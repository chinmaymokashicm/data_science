# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_raw = pd.read_csv('data.csv')

# %%
df_raw.head(3)
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
#    Data_Value_Unit Data_Value_Type  ...  \
# 0              NaN           Value  ...
# 1              NaN           Value  ...
# 2              NaN           Value  ...
#
# ...

# %%
df_raw[['x_geo', 'y_geo']]
# Out:
#                    x_geo                y_geo
# 0      32.84057112200048   -86.63186076199969
# 1      32.84057112200048   -86.63186076199969
# 2      32.84057112200048   -86.63186076199969
# 3      32.84057112200048   -86.63186076199969
# 4      32.84057112200048   -86.63186076199969
# ...                  ...                  ...
# 53387          18.335765           -64.896335
# 53388          18.335765           -64.896335
# 53389          18.335765           -64.896335
# 53390          18.335765           -64.896335
# 53391          18.335765           -64.896335
#
# [53392 rows x 2 columns]

# %%
x_coord = df_raw['GeoLocation'].str.split(',', expand=True)[0].str.split('(', expand=True)[1]
y_coord = df_raw['GeoLocation'].str.split(',', expand=True)[1].str.split(')', expand=True)[0]
# df_raw.insert(23, 'y_geo', y_coord)
# df_raw.insert(23, 'x_geo', x_coord)
# pd.Series(df_raw.columns)

# %%
pd.Series(df_raw.columns)
df_raw.columns
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'x_geo', 'y_geo', 'GeoLocation', 'ClassID', 'TopicID',
#        'QuestionID', 'DataValueTypeID', 'LocationID',
#        'StratificationCategory1', 'Stratification1',
#        'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %%
df_raw.iloc[:, 10:15]
# Out:
#        Data_Value  Data_Value_Alt Data_Value_Footnote_Symbol  \
# 0            32.0            32.0                        NaN
# 1            32.3            32.3                        NaN
# 2            31.8            31.8                        NaN
# 3            33.6            33.6                        NaN
# 4            32.8            32.8                        NaN
# ...           ...             ...                        ...
# 53387         NaN             NaN                          ~
# 53388         NaN             NaN                          ~
# 53389         NaN             NaN                          ~
# 53390         NaN             NaN                          ~
# 53391         NaN             NaN                          ~
#
#                                      Data_Value_Footnote  Low_Confidence_Limit
# 0                                                    NaN                  30.5
# ...

# %%
df_raw['Question'].unique()
# Out:
# array(['Percent of adults aged 18 years and older who have obesity',
#        'Percent of adults aged 18 years and older who have an overweight classification',
#        'Percent of adults who report consuming fruit less than one time daily',
#        'Percent of adults who report consuming vegetables less than one time daily',
#        'Percent of adults who engage in muscle-strengthening activities on 2 or more days a week',
#        'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic activity (or an equivalent combination)',
#        'Percent of adults who achieve at least 150 minutes a week of moderate-intensity aerobic physical activity or 75 minutes a week of vigorous-intensity aerobic physical activity and engage in muscle-strengthening activities on 2 or more days a week',
# ...

# %%
imp_rows_0 = ['YearStart', 'LocationDesc', 'Datasource', 'Question', 
       'Data_Value', 
       'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
       'Sample_Size', 'Age(years)', 'Education', 'Gender', 'Income',
       'Race/Ethnicity']
df_raw[imp_rows_0].head(3)
# Out:
#    YearStart LocationDesc                                  Datasource  \
# 0       2011      Alabama  Behavioral Risk Factor Surveillance System
# 1       2011      Alabama  Behavioral Risk Factor Surveillance System
# 2       2011      Alabama  Behavioral Risk Factor Surveillance System
#
#                                             Question  Data_Value  \
# 0  Percent of adults aged 18 years and older who ...        32.0
# 1  Percent of adults aged 18 years and older who ...        32.3
# 2  Percent of adults aged 18 years and older who ...        31.8
#
#   Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit   \
# 0                 NaN                  30.5                    33.5
# 1                 NaN                  29.9                    34.7
# 2                 NaN                  30.0                    33.6
#
#    Sample_Size Age(years) Education  Gender Income Race/Ethnicity
# 0       7304.0        NaN       NaN     NaN    NaN            NaN
# ...

# %%
df_g_loc = df_raw.groupby('LocationDesc')
df_g_loc.agg({
    'Data_Value': 'mean',
    # 'Age(years)': lambda x: float(x).mean(),
    # 'Age(years)': lambda x: float(x).max()
})
df_g_loc[pd.to_numeric(df_raw['Age(years)'], errors='coerce')].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-09cf5b22564b> in <module>
#       6 })
#       7 # df_g_loc.to_numeric(['Age(years)']).mean()
# ----> 8 df_g_loc[pd.to_numeric(df_raw['Age(years)'], errors='coerce')].mean()
#       9 # df_raw['Age(years)'].dtype
#
# ~/.local/lib/python3.6/site-packages/pandas/core/groupby/generic.py in __getitem__(self, key)
#    1601                 stacklevel=2,
#    1602             )
# -> 1603         return super().__getitem__(key)
#    1604
#    1605     def _gotitem(self, key, ndim: int, subset=None):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/base.py in __getitem__(self, key)
#     218             if len(self.obj.columns.intersection(key)) != len(key):
#     219                 bad_keys = list(set(key).difference(self.obj.columns))
# ...
